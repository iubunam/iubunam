# %%
# -*- coding: utf-8 -*-

"""
2020-06-04 V0.1 
- 코드 초안 작성 : 이전 코드 리마인드

2020-06-09 V0.2
- 코딩 순서 재구성 : 좌표 수정 -> 필요한 부분 선택
"""

#%% 모듈 불러오기


import pandas as pd

import os

import copy

import Dacharo_Data_Analysis_Module_V1 as DA

# %%
# 데이터 저장 폴더 설정
dataset_folder = 'dataset_sample\데이터셋 10Hz'

# 데이터 파일 이름 리스트
dataset_filename_list = os.listdir(dataset_folder)

# %%
""" 테스트 파일 샘플 """
dataset_filename = dataset_filename_list[0]
    
print(dataset_filename)
    
dataset_0 = pd.read_csv(os.path.join(dataset_folder, dataset_filename), sep = '\t', lineterminator='\r')
# Out:
# 02-01_상행_첨두_다차로-01_06_2020-16h03m51s.txt

# %%
dataset_0
# Out:
#        time  [00].VehicleUpdate-pos.001  [00].VehicleUpdate-pos.002  \
# 0       0.0                         NaN                         NaN
# 1       0.1                 -119.665077                -1813.449045
# 2       0.2                 -119.665608                -1813.447346
# 3       0.3                 -119.665722                -1813.447005
# 4       0.4                 -119.665911                -1813.446941
# ...     ...                         ...                         ...
# 2127  212.7                  499.188907                  629.733687
# 2128  212.8                  499.188907                  629.733687
# 2129  212.9                  499.188907                  629.733687
# 2130  213.0                  499.188907                  629.733687
# 2131  213.1                  499.188907                  629.733687
#
#       [00].VehicleUpdate-pos.003  [00].VehicleUpdate-pos.004  \
# 0                            NaN                         NaN
# 1                      27.726005                    2.150107
# 2                      27.717433                    2.150179
# 3                      27.711008                    2.150127
# 4                      27.706748                    2.150061
# ...                          ...                         ...
# 2127                   58.142079                    1.206845
# 2128                   58.142079                    1.206846
# 2129                   58.142079                    1.206846
# 2130                   58.142079                    1.206846
# 2131                   58.142079                    1.206846
#
#       [00].VehicleUpdate-pos.005  [00].VehicleUpdate-pos.006  \
# 0                            NaN                         NaN
# 1                       0.028032                    0.003614
# 2                       0.027869                    0.005777
# 3                       0.027244                    0.006046
# 4                       0.025732                    0.005581
# ...                          ...                         ...
# 2127                   -0.003607                   -0.001067
# 2128                   -0.003607                   -0.001067
# 2129                   -0.003607                   -0.001067
# 2130                   -0.003607                   -0.001067
# 2131                   -0.003607                   -0.001067
#
#       [01].VehicleUpdate-pos.001  [01].VehicleUpdate-pos.002  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                    -104.450622                -1847.578739
# ...                          ...                         ...
# 2127                  176.303515                 -212.714938
# 2128                  177.022332                 -210.844270
# 2129                  177.724858                 -209.016014
# 2130                  178.425548                 -207.192563
# 2131                  179.115835                 -205.396214
#
#       [01].VehicleUpdate-pos.003  ...  [98].VehicleUpdate-accel.004  \
# 0                            NaN  ...                           NaN
# 1                            NaN  ...                           NaN
# 2                            NaN  ...                           NaN
# 3                            NaN  ...                           NaN
# 4                      28.828890  ...                           NaN
# ...                          ...  ...                           ...
# 2127                   43.594716  ...                           0.0
# 2128                   43.645535  ...                           0.0
# 2129                   43.693337  ...                           0.0
# 2130                   43.739379  ...                           0.0
# 2131                   43.783368  ...                           0.0
#
#       [98].VehicleUpdate-accel.005  [98].VehicleUpdate-accel.006  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 2127                           0.0                           0.0
# 2128                           0.0                           0.0
# 2129                           0.0                           0.0
# 2130                           0.0                           0.0
# 2131                           0.0                           0.0
#
#       [99].VehicleUpdate-accel.001  [99].VehicleUpdate-accel.002  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 2127                     -0.000123                      0.000483
# 2128                      0.001018                      0.000000
# 2129                      0.000093                      0.000361
# 2130                      0.001154                      0.000503
# 2131                      0.000286                      0.000000
#
#       [99].VehicleUpdate-accel.003  [99].VehicleUpdate-accel.004  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 2127                           0.0                           0.0
# 2128                           0.0                           0.0
# 2129                           0.0                           0.0
# 2130                           0.0                           0.0
# 2131                           0.0                           0.0
#
#       [99].VehicleUpdate-accel.005  [99].VehicleUpdate-accel.006  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ...                            ...                           ...
# 2127                           0.0                           0.0
# 2128                           0.0                           0.0
# 2129                           0.0                           0.0
# 2130                           0.0                           0.0
# 2131                           0.0                           0.0
#
#       Last_TimeMarker
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 2127              NaN
# 2128              NaN
# 2129              NaN
# 2130              NaN
# 2131              NaN
#
# [2132 rows x 3080 columns]

# %%
from matplotlib import pyplot as plt
 
plt.plot([1,2,3], [110,130,120])
plt.show()
